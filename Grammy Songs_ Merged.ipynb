# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets
from pprint import pprint
from chart_studio.plotly import plot, iplot

# %%
grammy_songs_df = pd.read_csv ("BillboardFromLast20/grammySongs_1999-2019.csv")
grammy_songs_df
# Out:
#      Unnamed: 0    X                             GrammyAward  GrammyYear  \
# 0             1    0                      Record Of The Year        2018
# 1             2    1                        Song Of The Year        2018
# 2             3    2               Best Pop Solo Performance        2018
# 3             4    3          Best Pop Duo/Group Performance        2018
# 4             5    4                    Best Dance Recording        2018
# ..          ...  ...                                     ...         ...
# 423         424  423               Best Rap Solo Performance        1999
# 424         425  424  Best Rap Performance By A Duo Or Group        1999
# 425         426  425   Best Female Country Vocal Performance        1999
# 426         427  426     Best Male Country Vocal Performance        1999
# 427         428  427                       Best Country Song        1999
#
#                       Genre                                       Name  \
# ...

# %%
song_attributes_df = pd.read_csv ("BillboardFromLast20/songAttributes_1999-2019.csv")
song_attributes_df
# Out:
#         Unnamed: 0  Acousticness                             Album  \
# 0                0      0.000728  Collective Soul (Deluxe Version)
# 1                1      0.018200  Collective Soul (Deluxe Version)
# 2                2      0.000473  Collective Soul (Deluxe Version)
# 3                3      0.000970  Collective Soul (Deluxe Version)
# 4                4      0.000036  Collective Soul (Deluxe Version)
# ...            ...           ...                               ...
# 154926         114      0.333000       No.6 Collaborations Project
# 154927         115      0.314000       No.6 Collaborations Project
# 154928         116      0.467000       No.6 Collaborations Project
# 154929         117      0.110000       No.6 Collaborations Project
# 154930         118      0.000245       No.6 Collaborations Project
#
#                  Artist  Danceability  Duration  Energy  Explicit  \
# 0       Collective Soul         0.520    234947   0.904     False
# ...

# %%
song_attributes_df = pd.read_csv ("BillboardFromLast20/songAttributes_1999-2019.csv")
song_attributes_df
# Out:
#         Unnamed: 0  Acousticness                             Album  \
# 0                0      0.000728  Collective Soul (Deluxe Version)
# 1                1      0.018200  Collective Soul (Deluxe Version)
# 2                2      0.000473  Collective Soul (Deluxe Version)
# 3                3      0.000970  Collective Soul (Deluxe Version)
# 4                4      0.000036  Collective Soul (Deluxe Version)
# ...            ...           ...                               ...
# 154926         114      0.333000       No.6 Collaborations Project
# 154927         115      0.314000       No.6 Collaborations Project
# 154928         116      0.467000       No.6 Collaborations Project
# 154929         117      0.110000       No.6 Collaborations Project
# 154930         118      0.000245       No.6 Collaborations Project
#
#                  Artist  Danceability  Duration  Energy  Explicit  \
# 0       Collective Soul         0.520    234947   0.904     False
# ...

# %%
grammy_songs_df['Unique'] = grammy_songs_df['Name'] + grammy_songs_df['Artist']
grammy_songs_df
# Out:
#      Unnamed: 0    X                             GrammyAward  GrammyYear  \
# 0             1    0                      Record Of The Year        2018
# 1             2    1                        Song Of The Year        2018
# 2             3    2               Best Pop Solo Performance        2018
# 3             4    3          Best Pop Duo/Group Performance        2018
# 4             5    4                    Best Dance Recording        2018
# ..          ...  ...                                     ...         ...
# 423         424  423               Best Rap Solo Performance        1999
# 424         425  424  Best Rap Performance By A Duo Or Group        1999
# 425         426  425   Best Female Country Vocal Performance        1999
# 426         427  426     Best Male Country Vocal Performance        1999
# 427         428  427                       Best Country Song        1999
#
#                       Genre                                       Name  \
# ...

# %%
song_attributes_df['Unique'] = song_attributes_df['Name'] + song_attributes_df['Artist']
song_attributes_df
# Out:
#         Unnamed: 0  Acousticness                             Album  \
# 0                0      0.000728  Collective Soul (Deluxe Version)
# 1                1      0.018200  Collective Soul (Deluxe Version)
# 2                2      0.000473  Collective Soul (Deluxe Version)
# 3                3      0.000970  Collective Soul (Deluxe Version)
# 4                4      0.000036  Collective Soul (Deluxe Version)
# ...            ...           ...                               ...
# 154926         114      0.333000       No.6 Collaborations Project
# 154927         115      0.314000       No.6 Collaborations Project
# 154928         116      0.467000       No.6 Collaborations Project
# 154929         117      0.110000       No.6 Collaborations Project
# 154930         118      0.000245       No.6 Collaborations Project
#
#                  Artist  Danceability  Duration  Energy  Explicit  \
# 0       Collective Soul         0.520    234947   0.904     False
# ...

# %%
merged_songGrammy = grammy_songs_df.merge(song_attributes_df, on = 'Unique', how = 'inner')
merged_songGrammy
# Out:
#      Unnamed: 0_x    X                         GrammyAward  GrammyYear  \
# 0              14   13                       Best Rap Song        2018
# 1              21   20     Best American Roots Performance        2018
# 2              22   21            Best American Roots Song        2018
# 3              33   32    Best Traditional R&B Performance        2017
# 4              39   38  Best Country Duo/Group Performance        2017
# ..            ...  ...                                 ...         ...
# 139           415  414                Best Dance Recording        1999
# 140           416  415  Best Female Rock Vocal Performance        1999
# 141           417  416    Best Male Rock Vocal Performance        1999
# 142           417  416    Best Male Rock Vocal Performance        1999
# 143           421  420                      Best Rock Song        1999
#
#                     Genre               Name_x               Artist_x  \
# ...

# %%
merged_songGrammy.to_csv(r"BillboardFromLast20_Merged/merged_songGrammy.csv", index = False )
