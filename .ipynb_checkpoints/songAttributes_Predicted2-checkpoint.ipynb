# %%
from numpy.random import seed
seed(1)

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow

# %%
song_attributes_df = pd.read_csv ("BillboardFromLast20/songAttributes_1999-2019 copy 2.csv")
song_attributes_df
# Out:
#         Unnamed: 0  Acousticness                             Album  \
# 0                0      0.000728  Collective Soul (Deluxe Version)
# 1                1      0.018200  Collective Soul (Deluxe Version)
# 2                2      0.000473  Collective Soul (Deluxe Version)
# 3                3      0.000970  Collective Soul (Deluxe Version)
# 4                4      0.000036  Collective Soul (Deluxe Version)
# ...            ...           ...                               ...
# 154926         114      0.333000       No.6 Collaborations Project
# 154927         115      0.314000       No.6 Collaborations Project
# 154928         116      0.467000       No.6 Collaborations Project
# 154929         117      0.110000       No.6 Collaborations Project
# 154930         118      0.000245       No.6 Collaborations Project
#
#                  Artist  Danceability  Duration  Energy  Explicit  \
# 0       Collective Soul         0.520    234947   0.904     False
# 1       Collective Soul         0.581    239573   0.709     False
# 2       Collective Soul         0.572    198400   0.918     False
# 3       Collective Soul         0.596    231453   0.661     False
# 4       Collective Soul         0.520    222520   0.808     False
# ...                 ...           ...       ...     ...       ...
# 154926       Ed Sheeran         0.747    200733   0.649     False
# 154927       Ed Sheeran         0.469    204507   0.631     False
# 154928       Ed Sheeran         0.778    212307   0.590     False
# 154929       Ed Sheeran         0.726    190293   0.731     False
# 154930       Ed Sheeran         0.631    209120   0.796     False
#
#         Instrumentalness  Liveness  Loudness  Mode  \
# 0               0.010300    0.0634    -5.030     1
# 1               0.000664    0.1740    -4.909     1
# 2               0.000431    0.0977    -3.324     0
# 3               0.000033    0.1130    -5.051     1
# 4               0.000010    0.0800    -4.553     0
# ...                  ...       ...       ...   ...
# 154926          0.000000    0.1720    -6.218     0
# 154927          0.000000    0.1400    -6.569     0
# 154928          0.000000    0.0902    -5.548     1
# 154929          0.000003    0.0928    -6.304     0
# 154930          0.011500    0.3800    -5.350     1
#
#                                                      Name  Popularity  \
# 0                                       Welcome All Again          35
# 1                                                   Fuzzy          31
# 2                                                     Dig          30
# 3                                                     You          35
# 4                                                 My Days          21
# ...                                                   ...         ...
# 154926         Nothing On You (feat. Paulo Londra & Dave)          80
# 154927              I Dont Want Your Money (feat. H.E.R.)          74
# 154928  1000 Nights (feat. Meek Mill & A Boogie Wit da...          75
# 154929             Way To Break My Heart (feat. Skrillex)          73
# 154930           BLOW (with Chris Stapleton & Bruno Mars)          72
#
#        popularityLabel  Speechiness    Tempo  TimeSignature  Valence
# 0            Unpopular       0.0309  106.022              4    0.365
# 1            Unpopular       0.0282  120.027              4    0.408
# 2            Unpopular       0.0559  144.061              4    0.370
# 3            Unpopular       0.0254  111.975              4    0.183
# 4            Unpopular       0.0318   92.721              4    0.666
# ...                ...          ...      ...            ...      ...
# 154926         Popular       0.2190   88.011              4    0.840
# 154927         Popular       0.0853   91.418              4    0.763
# 154928         Popular       0.2700   97.995              4    0.515
# 154929         Popular       0.1590  170.125              4    0.430
# 154930         Popular       0.0401   92.469              4    0.596
#
# [154931 rows x 19 columns]

# %%
songAttributes=song_attributes_df.drop(columns=["Unnamed: 0","Album","Mode", "Name"])
songAttributes
# Out:
#         Acousticness           Artist  Danceability  Duration  Energy  \
# 0           0.000728  Collective Soul         0.520    234947   0.904
# 1           0.018200  Collective Soul         0.581    239573   0.709
# 2           0.000473  Collective Soul         0.572    198400   0.918
# 3           0.000970  Collective Soul         0.596    231453   0.661
# 4           0.000036  Collective Soul         0.520    222520   0.808
# ...              ...              ...           ...       ...     ...
# 154926      0.333000       Ed Sheeran         0.747    200733   0.649
# 154927      0.314000       Ed Sheeran         0.469    204507   0.631
# 154928      0.467000       Ed Sheeran         0.778    212307   0.590
# 154929      0.110000       Ed Sheeran         0.726    190293   0.731
# 154930      0.000245       Ed Sheeran         0.631    209120   0.796
#
#         Explicit  Instrumentalness  Liveness  Loudness  Popularity  \
# 0          False          0.010300    0.0634    -5.030          35
# 1          False          0.000664    0.1740    -4.909          31
# 2          False          0.000431    0.0977    -3.324          30
# 3          False          0.000033    0.1130    -5.051          35
# 4          False          0.000010    0.0800    -4.553          21
# ...          ...               ...       ...       ...         ...
# 154926     False          0.000000    0.1720    -6.218          80
# 154927     False          0.000000    0.1400    -6.569          74
# 154928     False          0.000000    0.0902    -5.548          75
# 154929     False          0.000003    0.0928    -6.304          73
# 154930     False          0.011500    0.3800    -5.350          72
#
#        popularityLabel  Speechiness    Tempo  TimeSignature  Valence
# 0            Unpopular       0.0309  106.022              4    0.365
# 1            Unpopular       0.0282  120.027              4    0.408
# 2            Unpopular       0.0559  144.061              4    0.370
# 3            Unpopular       0.0254  111.975              4    0.183
# 4            Unpopular       0.0318   92.721              4    0.666
# ...                ...          ...      ...            ...      ...
# 154926         Popular       0.2190   88.011              4    0.840
# 154927         Popular       0.0853   91.418              4    0.763
# 154928         Popular       0.2700   97.995              4    0.515
# 154929         Popular       0.1590  170.125              4    0.430
# 154930         Popular       0.0401   92.469              4    0.596
#
# [154931 rows x 15 columns]

# %%
songAttributes_binary_encoded = pd.get_dummies(songAttributes, columns=["Artist", "TimeSignature","Explicit"])
songAttributes_binary_encoded.head()
# Out:
#    Acousticness  Danceability  Duration  Energy  Instrumentalness  Liveness  \
# 0      0.000728         0.520    234947   0.904          0.010300    0.0634
# 1      0.018200         0.581    239573   0.709          0.000664    0.1740
# 2      0.000473         0.572    198400   0.918          0.000431    0.0977
# 3      0.000970         0.596    231453   0.661          0.000033    0.1130
# 4      0.000036         0.520    222520   0.808          0.000010    0.0800
#
#    Loudness  Popularity popularityLabel  Speechiness  ...  Artist_t.A.T.u.  \
# 0    -5.030          35       Unpopular       0.0309  ...                0
# 1    -4.909          31       Unpopular       0.0282  ...                0
# 2    -3.324          30       Unpopular       0.0559  ...                0
# 3    -5.051          35       Unpopular       0.0254  ...                0
# 4    -4.553          21       Unpopular       0.0318  ...                0
#
#    Artist_twenty one pilots  Artist_will.i.am  TimeSignature_0  \
# 0                         0                 0                0
# 1                         0                 0                0
# 2                         0                 0                0
# 3                         0                 0                0
# 4                         0                 0                0
#
#    TimeSignature_1  TimeSignature_3  TimeSignature_4  TimeSignature_5  \
# 0                0                0                1                0
# 1                0                0                1                0
# 2                0                0                1                0
# 3                0                0                1                0
# 4                0                0                1                0
#
#    Explicit_False  Explicit_True
# 0               1              0
# 1               1              0
# 2               1              0
# 3               1              0
# 4               1              0
#
# [5 rows x 1007 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
songAttributes_binary_encoded.columns
# Out:
# Index(['Acousticness', 'Danceability', 'Duration', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Popularity',
#        'popularityLabel', 'Speechiness',
#        ...
#        'Artist_t.A.T.u.', 'Artist_twenty one pilots', 'Artist_will.i.am',
#        'TimeSignature_0', 'TimeSignature_1', 'TimeSignature_3',
#        'TimeSignature_4', 'TimeSignature_5', 'Explicit_False',
#        'Explicit_True'],
#       dtype='object', length=1007)

# %%
X = songAttributes_binary_encoded.drop(["popularityLabel","Popularity","Artist_t.A.T.u.", "TimeSignature_1"], axis=1)
y = songAttributes_binary_encoded["popularityLabel"]
print(X.shape, y.shape)
# Out:
# (154931, 1003) (154931,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)
X_train.head()
# Out:
#         Acousticness  Danceability  Duration  Energy  Instrumentalness  \
# 79441         0.0406         0.640    180333   0.771          0.000002
# 40787         0.0609         0.712    235400   0.549          0.010300
# 86983         0.0739         0.742    249253   0.627          0.000000
# 124952        0.0201         0.471    185080   0.822          0.000000
# 153569        0.6490         0.186    223933   0.428          0.000145
#
#         Liveness  Loudness  Speechiness    Tempo  Valence  ...  \
# 79441     0.3260    -9.478       0.0306  138.745    0.860  ...
# 40787     0.1090    -9.665       0.1880   95.758    0.345  ...
# 86983     0.0796    -7.792       0.0457   92.994    0.597  ...
# 124952    0.1050    -8.017       0.0538  140.007    0.363  ...
# 153569    0.0877    -8.791       0.0320  163.975    0.273  ...
#
#         Artist_k.d. lang  Artist_matchbox twenty  Artist_twenty one pilots  \
# 79441                  0                       0                         0
# 40787                  0                       0                         0
# 86983                  0                       0                         0
# 124952                 0                       0                         0
# 153569                 0                       0                         0
#
#         Artist_will.i.am  TimeSignature_0  TimeSignature_3  TimeSignature_4  \
# 79441                  0                0                0                1
# 40787                  0                0                0                1
# 86983                  0                0                0                1
# 124952                 0                0                0                1
# 153569                 0                0                0                1
#
#         TimeSignature_5  Explicit_False  Explicit_True
# 79441                 0               1              0
# 40787                 0               1              0
# 86983                 0               1              0
# 124952                0               1              0
# 153569                0               1              0
#
# [5 rows x 1003 columns]

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=1003))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               100400
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 110,702
# Trainable params: 110,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 3632/3632 - 5s - loss: 0.1841 - accuracy: 0.9401
# Epoch 2/60
# 3632/3632 - 5s - loss: 0.1673 - accuracy: 0.9425
# Epoch 3/60
# 3632/3632 - 5s - loss: 0.1641 - accuracy: 0.9430
# Epoch 4/60
# 3632/3632 - 5s - loss: 0.1612 - accuracy: 0.9434
# Epoch 5/60
# 3632/3632 - 5s - loss: 0.1587 - accuracy: 0.9437
# Epoch 6/60
# 3632/3632 - 5s - loss: 0.1563 - accuracy: 0.9442

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1211/1211 - 2s - loss: 0.5467 - accuracy: 0.9217
# Normal Neural Network - Loss: 0.5466645359992981, Accuracy: 0.9217205047607422

# %%
encoded_predictions = model.predict_classes(X_test_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# WARNING:tensorflow:From <ipython-input-20-99cd25069996>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test)}")
# Out:
# Predicted classes: ['Unpopular' 'Unpopular' 'Unpopular' ... 'Unpopular' 'Unpopular'
#  'Unpopular']
# Actual Labels: ['Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Popular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Unpopular', 'Popular', 'Unpopular', 'Unpopular', ' ...

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
results = confusion_matrix(y_test, prediction_labels) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, prediction_labels))
print ('Report : ')
print (classification_report(y_test, prediction_labels) )
# Out:
# Confusion Matrix :
# [[  686  1710]
#  [ 1322 35015]]
# Accuracy Score : 0.9217204967340511
# Report :
#               precision    recall  f1-score   support
#
#      Popular       0.34      0.29      0.31      2396
#    Unpopular       0.95      0.96      0.96     36337
#
#     accuracy                           0.92     38733
#    macro avg       0.65      0.62      0.64     38733
# weighted avg       0.92      0.92      0.92     38733

# %%
model.save('model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-596723284980> in <module>
# ----> 1 model.save('model.h5')
#
# NameError: name 'model' is not defined
