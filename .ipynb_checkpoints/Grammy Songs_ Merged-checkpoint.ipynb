# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets
from pprint import pprint
from chart_studio.plotly import plot, iplot

# %%
grammy_albums_df = pd.read_csv ("BillboardFromLast20/grammySongs_1999-2019.csv")
grammy_albums_df
# Out:
#                                 grammyAward  grammyYear  \
# 0                        Record Of The Year        2018
# 1                          Song Of The Year        2018
# 2                 Best Pop Solo Performance        2018
# 3            Best Pop Duo/Group Performance        2018
# 4                      Best Dance Recording        2018
# ..                                      ...         ...
# 423               Best Rap Solo Performance        1999
# 424  Best Rap Performance By A Duo Or Group        1999
# 425   Best Female Country Vocal Performance        1999
# 426     Best Male Country Vocal Performance        1999
# 427                       Best Country Song        1999
#
#                       genre                                       name  \
# 0                   General                            this is America
# 1                   General                            this is America
# 2                       Pop  Joanne (where Do you Think You're Goin'?)
# ...

# %%
grammy_albums_df.count()
# Out:
# grammyAward    428
# grammyYear     428
# genre          428
# name           428
# artist         417
# dtype: int64

# %%
grammy_albums_df_clean = grammy_albums_df.dropna()

# %%
grammy_albums_df_clean.count()
# Out:
# grammyAward    417
# grammyYear     417
# genre          417
# name           417
# artist         417
# dtype: int64

# %%
song_attributes_df = pd.read_csv ("BillboardFromLast20/songAttributes_1999-2019.csv")
song_attributes_df
# Out:
#         acousticness                             album           artist  \
# 0           0.000728  Collective Soul (Deluxe Version)  Collective Soul
# 1           0.018200  Collective Soul (Deluxe Version)  Collective Soul
# 2           0.000473  Collective Soul (Deluxe Version)  Collective Soul
# 3           0.000970  Collective Soul (Deluxe Version)  Collective Soul
# 4           0.000036  Collective Soul (Deluxe Version)  Collective Soul
# ...              ...                               ...              ...
# 154926      0.333000       No.6 Collaborations Project       Ed Sheeran
# 154927      0.314000       No.6 Collaborations Project       Ed Sheeran
# 154928      0.467000       No.6 Collaborations Project       Ed Sheeran
# 154929      0.110000       No.6 Collaborations Project       Ed Sheeran
# 154930      0.000245       No.6 Collaborations Project       Ed Sheeran
#
#         danceability  duration  energy  explicit  instrumentalness  liveness  \
# ...

# %%
song_attributes_df.count ()
# Out:
# acousticness        154931
# album               154931
# artist              154931
# danceability        154931
# duration            154931
# energy              154931
# explicit            154931
# instrumentalness    154931
# liveness            154931
# loudness            154931
# mode                154931
# name                154931
# popularity          154931
# speechiness         154931
# tempo               154931
# timeSignature       154931
# valence             154931
# dtype: int64

# %%
grammy_albums_attributes_merge_df = pd.merge(grammy_albums_df_clean, song_attributes_df[['album','artist','danceability','energy','explicit','liveness','name']], on='name')
grammy_albums_attributes_merge_df
# Out:
#                               grammyAward  grammyYear                   genre  \
# 0                    Best Dance Recording        2018  Dance/Electronic Music
# 1                    Best Dance Recording        2018  Dance/Electronic Music
# 2           Best Country Solo Performance        2018                 Country
# 3           Best Country Solo Performance        2018                 Country
# 4           Best Country Solo Performance        2018                 Country
# ...                                   ...         ...                     ...
# 1250      Best Male R&B Vocal Performance        1999                     R&B
# 1251  Best Male Country Vocal Performance        1999                 Country
# 1252  Best Male Country Vocal Performance        1999                 Country
# 1253  Best Male Country Vocal Performance        1999                 Country
# 1254  Best Male Country Vocal Performance        1999                 Country
#
# ...
