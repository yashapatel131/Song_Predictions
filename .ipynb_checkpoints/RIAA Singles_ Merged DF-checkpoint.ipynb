# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets
from pprint import pprint
from chart_studio.plotly import plot, iplot

# %%
albums = pd.read_csv('BillboardFromLast20/grammyAlbums_199-2019.csv')
songs = pd.read_csv('BillboardFromLast20/grammySongs_1999-2019.csv')
riaa_album = pd.read_csv('BillboardFromLast20/riaaAlbumCerts_1999-2019.csv')
riaa_single = pd.read_csv('BillboardFromLast20/riaaSingleCerts_1999-2019.csv')
song_attributes = pd.read_csv('BillboardFromLast20/songAttributes_1999-2019.csv')

# %%
riaa_album.count()
# Out:
# Unnamed: 0    1731
# Album         1731
# Artist        1731
# Status        1731
# Label         1731
# dtype: int64

# %%
riaa_single['Unique'] = riaa_single['Name'] + riaa_single['Artist']
riaa_single
# Out:
#          X                  Name          Artist         RiaaStatus  \
# 0        0            Wish Wish        Dj Khaled               Gold
# 1        1              Level Up           Ciara        1x Platinum
# 2        2            Con Calma     Daddy Yankee        11x Diamond
# 3        3     Wish you Were Gay   Billie Eilish        1x Platinum
# 4        4             El Anillo  Jennifer Lopez  6x Multi-Platinum
# ...    ...                   ...             ...                ...
# 2596  2596          Heartbreaker    Mariah Carey               Gold
# 2597  2597        i Need to Know    Marc Anthony               Gold
# 2598  2598  She's all i Ever Had    Ricky Martin               Gold
# 2599  2599         i Want it all        Warren g               Gold
# 2600  2600              Unpretty             Tlc               Gold
#
#                                            Label  \
# 0                             We the Best / Epic
# ...

# %%
song_attributes['Unique'] = song_attributes['Name'] + song_attributes['Artist']
song_attributes
# Out:
#         Unnamed: 0  Acousticness                             Album  \
# 0                0      0.000728  Collective Soul (Deluxe Version)
# 1                1      0.018200  Collective Soul (Deluxe Version)
# 2                2      0.000473  Collective Soul (Deluxe Version)
# 3                3      0.000970  Collective Soul (Deluxe Version)
# 4                4      0.000036  Collective Soul (Deluxe Version)
# ...            ...           ...                               ...
# 154926         114      0.333000       No.6 Collaborations Project
# 154927         115      0.314000       No.6 Collaborations Project
# 154928         116      0.467000       No.6 Collaborations Project
# 154929         117      0.110000       No.6 Collaborations Project
# 154930         118      0.000245       No.6 Collaborations Project
#
#                  Artist  Danceability  Duration  Energy  Explicit  \
# 0       Collective Soul         0.520    234947   0.904     False
# ...

# %%
merged_riaa_single = riaa_single.merge(song_attributes, on = 'Unique', how = 'inner')
merged_riaa_single
# Out:
#          X             Name_x            Artist_x   RiaaStatus  \
# 0        1           Level Up               Ciara  1x Platinum
# 1        5              Rumor           Lee Brice  1x Platinum
# 2       12             Sucker      Jonas Brothers  1x Platinum
# 3       13             Uproar           Lil Wayne  1x Platinum
# 4       16          I'm Yours          Jason Mraz  10x Diamond
# ...    ...                ...                 ...          ...
# 1392  2583  What a Girl Wants  Christina Aguilera         Gold
# 1393  2585           Hot Boyz       Missy Elliott  1x Platinum
# 1394  2585           Hot Boyz       Missy Elliott  1x Platinum
# 1395  2592           Get Gone               Ideal         Gold
# 1396  2594              Candy         Mandy Moore         Gold
#
#                            Label                               Unique  \
# 0     Beauty Marks Entertainment                        Level UpCiara
# ...

# %%
merged_riaa_single.to_csv(r"BillboardFromLast20_Merged/merged_riaa_single.csv", index = False )
