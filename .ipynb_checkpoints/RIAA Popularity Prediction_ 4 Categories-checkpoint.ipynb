# %%
from numpy.random import seed
seed(1)

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
riaaSingle = pd.read_csv('BillboardFromLast20_Merged/merged_riaa_single.csv')
riaaSingle
# Out:
#          X             Name_x              Artist   RiaaStatus  \
# 0        1           Level Up               Ciara  1x Platinum
# 1        5              Rumor           Lee Brice  1x Platinum
# 2       12             Sucker      Jonas Brothers  1x Platinum
# 3       13             Uproar           Lil Wayne  1x Platinum
# 4       16          I'm Yours          Jason Mraz  10x Diamond
# ...    ...                ...                 ...          ...
# 1392  2583  What a Girl Wants  Christina Aguilera         Gold
# 1393  2585           Hot Boyz       Missy Elliott  1x Platinum
# 1394  2585           Hot Boyz       Missy Elliott  1x Platinum
# 1395  2592           Get Gone               Ideal         Gold
# 1396  2594              Candy         Mandy Moore         Gold
#
#                            Label                               Unique  \
# 0     Beauty Marks Entertainment                        Level UpCiara
# ...

# %%
riaaSingle1=riaaSingle.drop(columns=["X","Name_x", "RiaaStatus","Unique","Label","Unnamed: 0","Album","Artist_y","Mode", "Name_y"])
riaaSingle1
# Out:
#                   Artist  Acousticness  Danceability  Duration  Energy  \
# 0                  Ciara        0.0142         0.746    204150   0.825
# 1              Lee Brice        0.7490         0.655    198440   0.560
# 2         Jonas Brothers        0.0427         0.842    181027   0.734
# 3              Lil Wayne        0.0595         0.743    194184   0.870
# 4             Jason Mraz        0.5950         0.686    242187   0.457
# ...                  ...           ...           ...       ...     ...
# 1392  Christina Aguilera        0.0802         0.751    215120   0.819
# 1393       Missy Elliott        0.2890         0.749    215533   0.439
# 1394       Missy Elliott        0.3390         0.727    215467   0.445
# 1395               Ideal        0.4350         0.702    275173   0.520
# 1396         Mandy Moore        0.1780         0.813    234133   0.836
#
#       Explicit  Instrumentalness  Liveness  Loudness  Popularity  \
# ...

# %%
riaaSingle_binary_encoded = pd.get_dummies(riaaSingle1, columns=["Artist", "TimeSignature","Explicit"])
riaaSingle_binary_encoded.head()
# Out:
#    Acousticness  Danceability  Duration  Energy  Instrumentalness  Liveness  \
# 0        0.0142         0.746    204150   0.825            0.0107     0.121
# 1        0.7490         0.655    198440   0.560            0.0000     0.115
# 2        0.0427         0.842    181027   0.734            0.0000     0.106
# 3        0.0595         0.743    194184   0.870            0.0000     0.299
# 4        0.5950         0.686    242187   0.457            0.0000     0.105
#
#    Loudness  Popularity Popularity Calculated  Speechiness  ...  \
# 0    -4.666          65        Mildly Popular       0.1690  ...
# 1    -6.857          79               Popular       0.0486  ...
# 2    -5.065          81               Popular       0.0588  ...
# 3    -2.188          76               Popular       0.2120  ...
# 4    -8.322          42      Mildly Unpopular       0.0468  ...
#
#    Artist_Young Dro  Artist_Young Thug  Artist_Yung Joc  \
# 0                 0                  0                0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
riaaSingle_binary_encoded.columns
# Out:
# Index(['Acousticness', 'Danceability', 'Duration', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Popularity',
#        'Popularity Calculated', 'Speechiness',
#        ...
#        'Artist_Young Dro', 'Artist_Young Thug', 'Artist_Yung Joc',
#        'Artist_Zac Brown Band', 'TimeSignature_1', 'TimeSignature_3',
#        'TimeSignature_4', 'TimeSignature_5', 'Explicit_False',
#        'Explicit_True'],
#       dtype='object', length=323)

# %%
X = riaaSingle_binary_encoded.drop(["Popularity","Popularity Calculated", "Artist_Young Dro", "TimeSignature_3","Explicit_False"], axis=1)
y = riaaSingle_binary_encoded["Popularity Calculated"]
print(X.shape, y.shape)
# Out:
# (1397, 318) (1397,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)
X_train.head()
# Out:
#      Acousticness  Danceability  Duration  Energy  Instrumentalness  Liveness  \
# 188       0.56700         0.451    237853   0.233          0.000078    0.1190
# 189       0.11000         0.768    219692   0.282          0.020800    0.1130
# 491       0.00249         0.558    266960   0.670          0.000000    0.0689
# 897       0.32000         0.702     78200   0.826          0.000227    0.3550
# 242       0.23400         0.469    250627   0.708          0.000036    0.1150
#
#      Loudness  Speechiness    Tempo  Valence  ...  Artist_Yael Naim  \
# 188   -15.364       0.1090  136.680    0.302  ...                 0
# 189   -10.348       0.0863   97.043    0.175  ...                 0
# 491    -5.724       0.0275  105.982    0.373  ...                 0
# 897    -6.498       0.0529   80.014    0.329  ...                 0
# 242    -6.609       0.0485  169.744    0.791  ...                 0
#
#      Artist_Yandel  Artist_Yellowcard  Artist_Young Thug  Artist_Yung Joc  \
# ...

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=318))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=4, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               31900
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 404
# ...
# Total params: 42,404
# Trainable params: 42,404
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 33/33 - 0s - loss: 1.2580 - accuracy: 0.4174
# Epoch 2/60
# 33/33 - 0s - loss: 1.1891 - accuracy: 0.4317
# Epoch 3/60
# 33/33 - 0s - loss: 1.1572 - accuracy: 0.4441
# Epoch 4/60
# 33/33 - 0s - loss: 1.1062 - accuracy: 0.4967
# Epoch 5/60
# 33/33 - 0s - loss: 1.0351 - accuracy: 0.5626
# Epoch 6/60
# 33/33 - 0s - loss: 0.9540 - accuracy: 0.6208
# Epoch 7/60
# 33/33 - 0s - loss: 0.8768 - accuracy: 0.6476
# Epoch 8/60
# 33/33 - 0s - loss: 0.8242 - accuracy: 0.6628
# Epoch 9/60
# 33/33 - 0s - loss: 0.7905 - accuracy: 0.6676
# Epoch 10/60
# 33/33 - 0s - loss: 0.7614 - accuracy: 0.6590
# Epoch 11/60
# 33/33 - 0s - loss: 0.7240 - accuracy: 0.6762
# Epoch 12/60
# 33/33 - 0s - loss: 0.7082 - accuracy: 0.6762
# Epoch 13/60
# 33/33 - 0s - loss: 0.6860 - accuracy: 0.6934
# Epoch 14/60
# 33/33 - 0s - loss: 0.6673 - accuracy: 0.7030
# Epoch 15/60
# 33/33 - 0s - loss: 0.6529 - accuracy: 0.7049
# Epoch 16/60
# 33/33 - 0s - loss: 0.6358 - accuracy: 0.7192
# Epoch 17/60
# ...

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11/11 - 0s - loss: 1.8181 - accuracy: 0.5143
# Normal Neural Network - Loss: 1.8181416988372803, Accuracy: 0.5142857432365417

# %%
encoded_predictions = model.predict_classes(X_test_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# WARNING:tensorflow:From <ipython-input-20-99cd25069996>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test)}")
# Out:
# Predicted classes: ['Mildly Unpopular' 'Mildly Popular' 'Mildly Popular' 'Mildly Unpopular'
#  'Mildly Popular' 'Mildly Unpopular' 'Unpopular' 'Mildly Popular'
#  'Unpopular' 'Mildly Unpopular' 'Mildly Popular' 'Mildly Popular'
#  'Mildly Popular' 'Mildly Popular' 'Mildly Unpopular' 'Mildly Popular'
#  'Unpopular' 'Mildly Unpopular' 'Mildly Popular' 'Mildly Popular'
#  'Mildly Popular' 'Mildly Popular' 'Unpopular' 'Mildly Unpopular'
#  'Mildly Popular' 'Unpopular' 'Mildly Unpopular' 'Mildly Popular'
#  'Mildly Unpopular' 'Mildly Popular' 'Mildly Unpopular' 'Mildly Popular'
#  'Mildly Popular' 'Mildly Popular' 'Unpopular' 'Mildly Popular'
#  'Mildly Popular' 'Unpopular' 'Mildly Popular' 'Unpopular'
#  'Mildly Unpopular' 'Mildly Popular' 'Unpopular' 'Unpopular'
#  'Mildly Unpopular' 'Mildly Popular' 'Mildly Unpopular' 'Unpopular'
#  'Mildly Unpopular' 'Mildly Unpopular' 'Mildly Popular' 'Mildly Unpopular'
#  'Mildly Popular' 'Popular' 'Unpopular' 'Mildly Unpopular' 'Unpopular'
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
results = confusion_matrix(y_test, prediction_labels) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, prediction_labels))
print ('Report : ')
print (classification_report(y_test, prediction_labels) )
# Out:
# Confusion Matrix :
# [[104  30   5  18]
#  [ 35  34   1  22]
#  [  7   4   4   1]
#  [ 21  23   3  38]]
# Accuracy Score : 0.5142857142857142
# Report :
#                   precision    recall  f1-score   support
#
#   Mildly Popular       0.62      0.66      0.64       157
# Mildly Unpopular       0.37      0.37      0.37        92
#          Popular       0.31      0.25      0.28        16
#        Unpopular       0.48      0.45      0.46        85
#
#         accuracy                           0.51       350
#        macro avg       0.45      0.43      0.44       350
#     weighted avg       0.51      0.51      0.51       350
